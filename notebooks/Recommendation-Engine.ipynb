# %% [markdown]
# Recommendation Engine
#
# This is business intelligence.
#
# Example
#
# High Monthly Charges
#
# ↓
#
# Recommend
#
# Offer Discount
#
# Month-to-Month Contract
#
# ↓
#
# Offer 2-Year Contract
#
# No Tech Support
#
# ↓
#
# Offer Tech Support
#
# High Risk
#
# ↓
#
# Call Customer
#
# Build
#
# Recommendation Rules
#
# Business Logic
#
# Priority Ranking
