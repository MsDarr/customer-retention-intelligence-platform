# %% [markdown]
# Revenue Intelligence
#
# This is unique.
#
# Calculate
#
# Monthly Revenue
#
# Revenue at Risk
#
# Lost Revenue
#
# Potential Savings
#
# Campaign Cost
#
# ROI
#
# Executives care about this.
